# %%
import sounddevice as sd
import torch
from torch import nn
import torch.nn.functional as F
import torchaudio

# %%
data = torchaudio.datasets.LIBRISPEECH("./data", url="train-clean-100", download=True, folder_in_archive='LibriSpeech')

# %% [markdown]
# # Model Architecture

# %% [markdown]
# ## Conformer Block

# %% [markdown]
# ### MultiHeadAttention

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self):
        super().__init__()

# %%
class Conformer(nn.Module):
    def __init__(self):
        super().__init__()

# %%
torchaudio.models.Conformer(input_dim=64, num_heads=8, ffn_dim=128, num_layers=2, depthwise_conv_kernel_size=3)
# Out:
# Conformer(
#   (conformer_layers): ModuleList(
#     (0): ConformerLayer(
#       (ffn1): _FeedForwardModule(
#         (sequential): Sequential(
#           (0): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           (1): Linear(in_features=64, out_features=128, bias=True)
#           (2): SiLU()
#           (3): Dropout(p=0.0, inplace=False)
#           (4): Linear(in_features=128, out_features=64, bias=True)
#           (5): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (self_attn_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       (self_attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#       )
#       (self_attn_dropout): Dropout(p=0.0, inplace=False)
#       (conv_module): _ConvolutionModule(
#         (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (sequential): Sequential(
# ...
